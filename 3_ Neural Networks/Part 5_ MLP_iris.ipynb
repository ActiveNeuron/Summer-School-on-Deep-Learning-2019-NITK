# %% [markdown]
# ## Summer School on Deep Learning-2019 Surathkal, Karnataka

# %% [markdown]
# ### Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python2.7/dist-packages/google/colab/drive.pyc in mount(mountpoint, force_remount, timeout_ms)
#     182       # Not already authorized, so do the authorization dance.
#     183       auth_prompt = d.match.group(1) + '\n\nEnter your authorization code:\n'
# --> 184       d.send(_getpass.getpass(auth_prompt) + '\n')
#     185   d.sendcontrol('z')
#     186   d.expect(u'Stopped')
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in getpass(self, prompt, stream)
#     686             self._parent_ident,
#     687             self._parent_header,
# --> 688             password=True,
#     689         )
#     690
#
# /usr/local/lib/python2.7/dist-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import os
os.chdir('/content/drive/My Drive/SSDL/Day1/Image')
print(os.getcwd())
# Out:
# /content/drive/My Drive/SSDL/Day1/Image

# %% [markdown]
# ### IRIS Dataset
# *  The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".
#
# *  The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.

# %%
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/IRIS1.jpg', embed=True))

# %%
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/IRIS3.png', embed=True))

# %%
import cv2
import matplotlib.pyplot as plt
a = cv2.imread('/content/drive/My Drive/SSDL/Day1/Image/IRIS1.jpg')
a = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)
b = cv2.imread('/content/drive/My Drive/SSDL/Day1/Image/IRIS2.png')
b = cv2.cvtColor(b,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(15,15))
plt.subplot(121).imshow(a)
plt.subplot(122).imshow(b)

# %% [markdown]
# #### Importing the dataset

# %%
from  sklearn import  datasets
iris=datasets.load_iris()

# %%
x=iris.data
y=iris.target

# %% [markdown]
# #### Splitting the data into test and train

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=1234, stratify=y)
#random_state is the seed used by the random number generator
# stratify: If not None, data is split in a stratified fashion, using this as the class labels.

# %%
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# #### Model without Normalization

# %%
mlp0 = MLPClassifier(hidden_layer_sizes=5, activation='logistic', max_iter=500)  
mlp0.fit(x_train, y_train)
predictions = mlp0.predict(x_test)  
print " Score: ",mlp0.score(x_test,y_test),"with hidden Layer Size : ",mlp0.hidden_layer_sizes," without standardization"
# Out:
#  Score:  0.72 with hidden Layer Size :  5  without standardization
# /usr/local/lib/python2.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# #### Model with Normaliztion

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(x_train)

x_train = scaler.transform(x_train)  
x_test = scaler.transform(x_test)

# %%
mlps = MLPClassifier(hidden_layer_sizes=5, activation='logistic', max_iter=500)  
mlps.fit(x_train, y_train)
predictions = mlps.predict(x_test)  
print " Score: ",mlps.score(x_test,y_test),"with hidden Layer Size : ",mlps.hidden_layer_sizes," with standardization"
# Out:
#  Score:  0.84 with hidden Layer Size :  5  with standardization

# %% [markdown]
# **Reference**
#
# For further explaination please refer the link below :
#
# https://medium.com/@urvashilluniya/why-data-normalization-is-necessary-for-machine-learning-models-681b65a05029

# %% [markdown]
# ### Assignments

# %% [markdown]
# #### Experiment with Different Activation Functions
# * Identity (Linear)
# * logistic (Sigmoid)
# * tanh
# * relu

# %%
#'identity'
mlp4 = MLPClassifier(hidden_layer_sizes=(5,5),max_iter=1000,activation='',random_state = 0) #Add identity activation function
mlp4.fit(x_train,y_train)
print "\nScore: ", mlp4.score(x_test,y_test), " with Activation function :  ",mlp4.activation,
# Out:
# Score:  0.96  with Activation function :   identity

# %%
#'logistic'
mlp4 = MLPClassifier(hidden_layer_sizes=(5,5),max_iter=1000,activation='',random_state = 0) #Add logistic activation function
mlp4.fit(x_train,y_train)
print "\nScore: ", mlp4.score(x_test,y_test), " with Activation function :  ",mlp4.activation,

# %%
#'tanh'
mlp4 = MLPClassifier(hidden_layer_sizes=(5,5),max_iter=1000,activation='',random_state = 0) #Add tanh activation function
mlp4.fit(x_train,y_train)
print "\nScore: ", mlp4.score(x_test,y_test), " with Activation function :  ",mlp4.activation,
# Out:
# Score:  0.96  with Activation function :   tanh

# %%
#'relu'
mlp4 = MLPClassifier(hidden_layer_sizes=(5,5),max_iter=1000,activation='',random_state = 0) #Add relu activation function
mlp4.fit(x_train,y_train)
print "\nScore: ", mlp4.score(x_test,y_test), " with Activation function :  ",mlp4.activation,
# Out:
# Score:  1.0  with Activation function :   relu
# /usr/local/lib/python2.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
