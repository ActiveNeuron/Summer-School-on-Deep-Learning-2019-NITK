# %% [markdown]
# ## Summer School on Deep Learning-2019 Surathkal, Karnataka

# %% [markdown]
# ### Gates Implementation using Perceptron

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# #### Mounting

# %%
import os
os.chdir('/content/drive/My Drive/SSDL/Day1/Image')
print(os.getcwd())
# Out:
# /content/drive/My Drive/SSDL/Day1/Image

# %%
# Perceptron
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/Perceptron.png', embed=True))

# %% [markdown]
# #### Weight Initialization

# %%
import numpy as np

#Function for initializing random weights
def init_weights():
	W = np.random.rand(1,2)    # random array of 1 row and two columns
	b = 0                      # Bias allows you to shift the activation function by adding a constant  to the input
	return W, b

# %% [markdown]
# #### Step Function  :

# %%
def step(z):
	return 1 * (z > 0)             # returns non-zero values

# %% [markdown]
# #### Forward Propagation

# %%
def propagate(W,b,X,Y):	
	A = step(np.dot(X,W.T) + b)    # T : Transpose of matrix
	Error = Y - A
	return Error

# %% [markdown]
# #### Optimization

# %%
def optimize(W,b,X,Y,num_iterations, learning_rate):
	for i in range(num_iterations):
		Error = propagate(W,b,X,Y)
		print(Error)
		print ("Error is {} for iteration {}".format(np.mean(Error), i+1))
		W = W + np.multiply(learning_rate , (np.dot(Error.T,X))) 
		b = b + np.multiply(learning_rate ,np.mean( Error))
	params = {"W" : W, "b" : b}
	return params

# %% [markdown]
# #### Model

# %%
def model(X,Y,num_iterations,learning_rate):
	W, b = init_weights()
	print ("Initial W is {} and b is {}".format(W,b))
	params = optimize(W,b,X,Y,num_iterations, learning_rate)
	print ("Final updated W and b are")
	print ("W is" ,params["W"])
	print ("b is ",params["b"])
	return params

# %%
def validation(X,params):
	W = params["W"]
	b = params["b"]
	A = step(np.dot(X,W.T) + b)
	return  A

# %% [markdown]
# **OR GATE**

# %%
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/OR.png', embed=True))

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])

learning_rate = 0.2
num_of_interations = 10
	
Y_OR = np.array([0,1,1,1]).reshape((4,1))

params = model(X, Y_OR,num_of_interations,learning_rate)
print ("X is input {} \n corresponding Y as output {}".format(X,step(validation(X,params))))

predictions=validation(X,params)
#print(predictions)
acc = np.mean(Y_OR==predictions)
print("Accuracy is {}%".format(acc*100))
# Out:
# Initial W is [[0.31289539 0.64066045]] and b is 0
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 1
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 2
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 3
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 4
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 5
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 6
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 7
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 8
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 9
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 10
# Final updated W and b are
# W is [[0.31289539 0.64066045]]
# b is  0.0
# X is input [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
#  corresponding Y as output [[0]
#  [1]
#  [1]
#  [1]]
# Accuracy is 100.0%

# %% [markdown]
# **AND GATE**

# %%
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/AND.png', embed=True))

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])

learning_rate = 0.2
num_of_interations = 10     #If doesn't converge in 10, increase
	
Y_AND = np.array([0,0,0,1]).reshape((4,1))

params = model(X, Y_AND,num_of_interations,learning_rate)
print ("X is input {} \n corresponding Y as output {}".format(X,step(validation(X,params))))

predictions=validation(X,params)
acc = np.mean(Y_AND==predictions)
print("Accuracy is {}%".format(acc*100))
# Out:
# Initial W is [[0.65543242 0.94963328]] and b is 0
# [[ 0]
#  [-1]
#  [-1]
#  [ 0]]
# Error is -0.5 for iteration 1
# [[ 0]
#  [-1]
#  [-1]
#  [ 0]]
# Error is -0.5 for iteration 2
# [[ 0]
#  [-1]
#  [-1]
#  [ 0]]
# Error is -0.5 for iteration 3
# [[ 0]
#  [-1]
#  [ 0]
#  [ 0]]
# Error is -0.25 for iteration 4
# [[0]
#  [0]
#  [0]
#  [1]]
# Error is 0.25 for iteration 5
# [[ 0]
#  [-1]
#  [ 0]
#  [ 0]]
# Error is -0.25 for iteration 6
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 7
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 8
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 9
# [[0]
#  [0]
#  [0]
#  [0]]
# Error is 0.0 for iteration 10
# Final updated W and b are
# W is [[0.25543242 0.14963328]]
# b is  -0.35000000000000003
# X is input [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
#  corresponding Y as output [[0]
#  [0]
#  [0]
#  [1]]
# Accuracy is 100.0%

# %% [markdown]
# **XOR GATE**

# %%
from IPython.display import Image, display
display(Image(filename='/content/drive/My Drive/SSDL/Day1/Image/XOR.png', embed=True))

# %%
import numpy as np
X = np.array([[0,0],[0,1],[1,0],[1,1]])

learning_rate = 0.2
num_of_interations = 10
	
Y_XOR = np.array([0,1,1,0]).reshape((4,1))

params = model(X, Y_XOR,num_of_interations,learning_rate)
print ("X is input {} \n corresponding Y as output {}".format(X,step(validation(X,params))))

predictions=validation(X,params)
print("Predicted output : ")
print(predictions)
acc = np.mean(Y_XOR==predictions)
print("Accuracy is {}%".format(acc*100))

# https://computing.dcu.ie/~humphrys/Notes/Neural/single.neural.html
# Out:
# Initial W is [[0.7468759  0.52585578]] and b is 0
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 1
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 2
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 3
# [[0]
#  [1]
#  [1]
#  [0]]
# Error is 0.5 for iteration 4
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 5
# [[0]
#  [1]
#  [0]
#  [0]]
# Error is 0.25 for iteration 6
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 7
# [[0]
#  [1]
#  [1]
#  [0]]
# Error is 0.5 for iteration 8
# [[ 0]
#  [ 0]
#  [ 0]
#  [-1]]
# Error is -0.25 for iteration 9
# [[0]
#  [1]
#  [1]
#  [0]]
# Error is 0.5 for iteration 10
# Final updated W and b are
# W is [[0.1468759  0.12585578]]
# b is  0.04999999999999999
# X is input [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
#  corresponding Y as output [[1]
#  [1]
#  [1]
#  [1]]
# Predicted output :
# [[1]
#  [1]
#  [1]
#  [1]]
# Accuracy is 50.0%

# %% [markdown]
# For further explaination on XOR problem, please refer the site below :
#  https://computing.dcu.ie/~humphrys/Notes/Neural/single.neural.html
