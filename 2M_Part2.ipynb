# %% [markdown]
# # Python Basics
# 1. String Declaration and printing its type
# >Experiments with Strings
# 2. Variable declaration
# >Experiments with Strings

# %%
a = "sachinn"

print("Before Capitalizing :", a)
print("After capitalizing  :", a.capitalize())   #Complete the code
# Out:
# Before Capitalizing : sachinn
# After capitalizing  : Sachinn

# %%
print("Before Converting to Uppercase :", a)
print("After  Converting to Uppercase :",a.upper() ) #Complete the code
# Out:
# Before Converting to Uppercase : sachinn
# After  Converting to Uppercase : SACHINN

# %%
b = "SACHIN"
print("Before Converting to Lowercase :", b)
print("After  Converting to Lowercase :", a.lower()) #Complete the code
# Out:
# Before Converting to Lowercase : SACHIN
# After  Converting to Lowercase : sachinn

# %%
print("Before Replace  :", a)
print("After Replace   :",  a.replace('s','S'))#Complete the code
# Out:
# Before Replace  : sachinn
# After Replace   : Sachinn

# %% [markdown]
# #### Assignement-1
# ##### Print the following output:
# * Sachin's score
# * Sachin's "score"
# * Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin
# * c:\docs\nithin'

# %%
print("Sachin'"+"s"+" score")
print("Sachin's score")
print('Sachin\'s "laptop"')
print(10*"Sachin ")
print('c:\docs\nithin')
print(r'c:\docs\nithin')
# Out:
# Sachin's score
# Sachin's score
# Sachin's "laptop"
# Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin Sachin
# c:\docs
# ithin
# c:\docs\nithin

# %%
a = 5.0
type(a)

# %%
a = 0.100000000000000000001
a
# Out:
# 0.1

# %%
0.100000000000000000001 == 0.1
# Out:
# True

# %%
b= 0.1245896557
b
# Out:
# 0.1245896557

# %%
y1 = format(b,'.3f')
print(y1)
# Out:
# 0.125

# %%
#Input from user
a = int(input())
print(a)

# %%
b = float(input())
print(b)
# Out:
# 2.2
# 2.2

# %%
#Declaring Boolean variable

# %%
a = True
type(a)
# Out:
# bool

# %%
#Declare Complex Numabers: Type1
a = num = 5+8j
type(num)
# Out:
# complex

# %%
#Declare Complex Numabers: Type2
a = 5
b = 6
complex(a,b)

# %%
c = str(input())
print(c)
# Out:
# abc
# abc

# %% [markdown]
# # Mathematical Operations
# * Addition
# * Subtraction
# * Multiplication
# * Division
# * Ceil
# * Floor
# * GCD
# * Bodmas
# * Modulus
# *Underscore

# %%
a = 10
b = 5

print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
# Out:
# 15
# 5
# 50
# 100000
# 2.0

# %%
#Modulus
5%2
# Out:
# 1

# %%
a=10
a
# Out:
# 10

# %%
#Underscore
c = _+10
c
# Out:
# 20

# %%
a = -10
b = 5

# %%
#Absolute Keyword
print(abs(a*b))
# Out:
# 50

# %%
#round
a = 5.8
print(round(a))
# Out:
# 6

# %%
import math
print(math.ceil(4.5))
print(math.floor(4.5))
print(math.gcd(10,5))
print(math.e)
print(math.pi)
# Out:
# 5
# 4
# 5
# 2.718281828459045
# 3.141592653589793

# %%
# Increments
x = 2
print(x)
x = x+2
print(x)
x+=2
print(x)

# %%
#Multiple Assignment
a,b= 5,6
print(a)
print(b)
# Out:
# 5
# 6

# %%
#Operaors (</>)

a = 5
b = 6

print(a<8 and b>9)
print(a<8 or b>9)

# %%
#swap
a = 5
b = 6

print(a)
print(b)

temp = a
a = b
b = temp

print(a)
print(b)
# Out:
# 5
# 6
# 6
# 5

# %%
#swap 2
a = 5
b = 6
print(a)
print(b)

a,b = b,a

print(a)
print(b)
